# %%
import pandas as pd

# %%
# %%sql
# SELECT * FROM pml.mv_pymc_accounting_anomaly
# Out:
#               isin ticker            trading_region                    region  \
# 0     US29275Y1029    ENS  United States and Canada  United States and Canada
# 1     US3434121022    FLR  United States and Canada  United States and Canada
# 2     GB00B1JQDM80   MARS                    Europe                    Europe
# 3     IL0002810146    ICL  United States and Canada      Africa / Middle East
# 4     US53947R1059   LOAR  United States and Canada  United States and Canada
# ...            ...    ...                       ...                       ...
# 6400  US78454L1008     SM  United States and Canada  United States and Canada
# 6401  US03783C1009   APPF  United States and Canada  United States and Canada
# 6402  US4330001060   HIMS  United States and Canada  United States and Canada
# 6403  US90184D1000   TWST  United States and Canada  United States and Canada
# 6404  JE00BS44BN30   BIRK  United States and Canada                    Europe
#
# ...

# %%
anomaly_df.describe()
# Out:
#        observed_eps_adj  feat_accruals_ratio  feat_gpm_change_1y  \
# count       3615.000000          5827.000000         6124.000000
# mean           2.590844            -0.106892            0.031060
# std           10.317122             4.366110            1.367713
# min         -105.860000          -316.676378          -53.772358
# 25%            0.080000            -0.077852           -0.035439
# 50%            0.690000            -0.033261            0.005876
# 75%            2.910000            -0.008698            0.055981
# max          385.590000            48.847879           36.000000
#
#        feat_sales_growth_1y  feat_ebit_growth_1y  feat_ebitda_growth_1y  \
# count           5809.000000          5837.000000            5823.000000
# mean               0.515815             0.456782              -0.368939
# std                9.450661            29.356977              33.929540
# min               -5.829487          -712.500000           -2555.666667
# ...

# %%
anomaly_df.hist(figsize=(20,12))
# Out:
# array([[<Axes: title={'center': 'observed_eps_adj'}>,
#         <Axes: title={'center': 'feat_accruals_ratio'}>,
#         <Axes: title={'center': 'feat_gpm_change_1y'}>,
#         <Axes: title={'center': 'feat_sales_growth_1y'}>],
#        [<Axes: title={'center': 'feat_ebit_growth_1y'}>,
#         <Axes: title={'center': 'feat_ebitda_growth_1y'}>,
#         <Axes: title={'center': 'feat_capex_intensity'}>,
#         <Axes: title={'center': 'feat_eps_adj_gap'}>],
#        [<Axes: title={'center': 'feat_cfi_to_cfo'}>,
#         <Axes: title={'center': 'feat_cff_to_cfo'}>,
#         <Axes: title={'center': 'feat_share_inflation_1y'}>,
#         <Axes: title={'center': 'feat_issuance_intensity'}>],
#        [<Axes: title={'center': 'feat_employee_growth_1y'}>,
#         <Axes: title={'center': 'feat_fcfps_vs_eps_gap'}>,
#         <Axes: title={'center': 'feat_peg_ntm'}>,
#         <Axes: title={'center': 'feat_mcap_trend_1y'}>],
# ...
