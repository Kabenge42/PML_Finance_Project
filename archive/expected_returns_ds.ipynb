# %%
# %%sql
# # SELECT * FROM expected_returns_summary
# Out:
#               isin  ticker                                        name  \
# 0     US89532M1018    TRVI                     Trevi Therapeutics Inc.
# 1     CNE0000016J9  600309              Wanhua Chemical Group Co. Ltd.
# 2     US2561631068    DOCU                               DocuSign Inc.
# 3     BRDESKACNOR2   DESK3                                Desktop S.A.
# 4     KYG4402L1510    1044  Hengan International Group Company Limited
# ...            ...     ...                                         ...
# 5526  BE0974259880     DIE                          D'Ieteren Group SA
# 5527  IE00BWY4ZF18     CRN                             Cairn Homes plc
# 5528  FR0000032526     GBT                                  Guerbet SA
# 5529  CA7739151032    RGSI                  Rockpoint Gas Storage Inc.
# 5530  FR0000050353     FII                                   Lisi S.A.
#
#                                             description  \
# 0     Trevi Therapeutics Inc. a clinical-stage bioph...
# ...

# %%
df.describe()
# Out:
#        reporting_interval    last_price    var_5_pct  risk_reward_ratio  \
# count         5531.000000  5.531000e+03  5531.000000        5531.000000
# mean             4.950461  5.981711e+03     9.496326           3.971227
# std              1.523441  6.518361e+04    32.274139          20.980560
# min              0.000000  3.450000e-02   -95.731522        -923.905153
# 25%              3.000000  1.400000e+01    -8.971210           0.804764
# 50%              6.000000  4.210000e+01     5.974946           2.203161
# 75%              6.000000  1.539250e+02    22.373583           4.051807
# max              6.000000  2.546000e+06   408.559703         552.342544
#
#        expected_upside_pct  price_target_mc  prob_positive_upside  \
# count          5531.000000     5.531000e+03           5531.000000
# mean             29.817500     6.943791e+03             83.516076
# std              40.537331     8.011371e+04             27.371714
# ...

# %%
df.head(10)
# Out:
#            isin  ticker                                        name  \
# 0  US89532M1018    TRVI                     Trevi Therapeutics Inc.
# 1  CNE0000016J9  600309              Wanhua Chemical Group Co. Ltd.
# 2  US2561631068    DOCU                               DocuSign Inc.
# 3  BRDESKACNOR2   DESK3                                Desktop S.A.
# 4  KYG4402L1510    1044  Hengan International Group Company Limited
#
#                                          description  \
# 0  Trevi Therapeutics Inc. a clinical-stage bioph...
# 1  Wanhua Chemical Group Co. Ltd. provides polyur...
# 2  DocuSign Inc. provides electronic signature so...
# 3  Desktop S.A. provides fixed telephony broadban...
# 4  Hengan International Group Company Limited an ...
#
#                         region country trading_country  exchange  \
# 0     United States and Canada      US              US  NasdaqGM
# 1               Asia / Pacific      CN              CN      SHSE
# ...
